# %%
import datajoint as dj
dj.config.load("dj_local_conf.json")

import numpy as np
from spyglass.position import PositionOutput
import spyglass.common as sgc
import pandas as pd
from behavior.wtrack_tables_dmr import WTrackParams, WTrackSelection, WTrackEvents
# Out:
# [2026-01-19 11:23:21,778][INFO]: DataJoint is configured from /home/dmrodriguez/mPFC-opto/notebooks/dj_local_conf.json

# %%
WTrackParams().insert_default()

# %%
nwb_file_name = 'Jacob20250618_.nwb'

# %%
pos_key = {
    "nwb_file_name": nwb_file_name,
    "epoch": 2,
    "project_name": "w-track_Jacob"
}
merge_id = (PositionOutput.DLCPosV1() & pos_key).fetch1("merge_id")

# %%
WTrackSelection().insert1(
                          {'wtrack_params_name': 'default',
                           'nwb_file_name': 'Jacob20250618_.nwb',
                           'pos_merge_id': merge_id,
                           'epoch': 2,
                           'statescript_path': '/stelmo/denisse/Jacob/raw/20250618/20250618_Jacob_02_r1/20250618_Jacob_02_r1.stateScriptLog'}, skip_duplicates = True)

# %%
WTrackSelection()
# Out:
# *wtrack_params *nwb_file_name *pos_merge_id  epoch     statescript_pa
# +------------+ +------------+ +------------+ +-------+ +------------+
# default        Jacob20250618_ 1147f403-e92d- 6         /stelmo/deniss
# default        Jacob20250618_ 512703a2-e969- 8         /stelmo/deniss
# default        Jacob20250618_ 9545ee3b-1c8c- 2         /stelmo/deniss
# default        Jacob20250618_ fee628e1-7a63- 10        /stelmo/deniss
# default_Seth   Seth20251210_. 2be6a409-851a- 2         /stelmo/deniss
# no_validation  Jacob20250618_ e8dd2df4-b052- 4
# no_validation  Jacob20250619_ d74b4e0c-7003- 2
#  (Total: 7)

# %%
key = {'wtrack_params_name': 'default',
                           'nwb_file_name': 'Jacob20250618_.nwb',
                           'pos_merge_id': merge_id,
                           'epoch': 2,
                           'statescript_path': '/stelmo/denisse/Jacob/raw/20250618/20250618_Jacob_02_r1/20250618_Jacob_02_r1.stateScriptLog'}

# %%
WTrackEvents().populate(key)

# %%
WTrackEvents()
# Out:
# *wtrack_params *nwb_file_name *pos_merge_id  epoch     wtrack_res validation n_events     analysis_file_ trial_object_i
# +------------+ +------------+ +------------+ +-------+ +--------+ +--------+ +----------+ +------------+ +------------+
# default        Jacob20250618_ 1147f403-e92d- 6         =BLOB=     =BLOB=     8            Jacob20250618_ 35711a48-2e7e-
# default        Jacob20250618_ 512703a2-e969- 8         =BLOB=     =BLOB=     1            Jacob20250618_ a075d3cd-90c5-
# default        Jacob20250618_ 9545ee3b-1c8c- 2         =BLOB=     =BLOB=     32           Jacob20250618_ d96bfa10-1ea6-
# default        Jacob20250618_ fee628e1-7a63- 10        =BLOB=     =BLOB=     24           Jacob20250618_ 9b9a9059-0e34-
# default_Seth   Seth20251210_. 2be6a409-851a- 2         =BLOB=     =BLOB=     41           Seth20251210_Z 3675f84a-e730-
# no_validation  Jacob20250618_ e8dd2df4-b052- 4         =BLOB=     =BLOB=     22           Jacob20250618_ ddd7f193-44ab-
# no_validation  Jacob20250619_ d74b4e0c-7003- 2         =BLOB=     =BLOB=     56           Jacob20250619_ e6119c8f-dd50-
#  (Total: 7)

# %%
x = (WTrackEvents() & {'nwb_file_name': nwb_file_name}).fetch('validation_report')
x

# %%
x = (WTrackEvents() & {'epoch': 2}).fetch('wtrack_results')
y = pd.DataFrame(x[0])
y
y

# %%
x = (WTrackEvents() & {'epoch': 2}).fetch('wtrack_results')
y = pd.DataFrame(x[0])
y
y
