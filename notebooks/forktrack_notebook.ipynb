# %%
import datajoint as dj
dj.config.load("dj_local_conf.json")

import sys
import os
sys.path.insert(0, os.path.abspath('../src'))

import numpy as np
from spyglass.position import PositionOutput
import spyglass.common as sgc
import pandas as pd
from behavior.forktrack_tables_dmr import ForkTrackParams, ForkTrackSelection, ForkTrackEvents
# Out:
# [2026-07-15 16:54:44,841][INFO]: DataJoint is configured from /home/dmrodriguez/mPFC-opto/notebooks/dj_local_conf.json

# %%
ForkTrackParams().insert_default()

# %%
nwb_file_name = 'Caius20260623_.nwb'

# %%
pos_key = {
    "nwb_file_name": nwb_file_name,
    "epoch": 10,
}
merge_id = (PositionOutput.DLCPosV1() & pos_key).fetch1("merge_id")

# %%
ForkTrackSelection()
# Out:
# *forktrack_par *nwb_file_name *pos_merge_id  epoch     statescript_pa
# +------------+ +------------+ +------------+ +-------+ +------------+
# default        Caius20260623_ 511a2056-0dff- 2         /stelmo/deniss
# default        Caius20260623_ 595f4360-7eeb- 4         /stelmo/deniss
# default        Caius20260623_ 5f1240f9-46c7- 6         /stelmo/deniss
# default        Caius20260623_ 664c41c2-1ba5- 8         /stelmo/deniss
#  (Total: 4)

# %%
ForkTrackSelection().insert1(
                          {'forktrack_params_name': 'default',
                           'nwb_file_name': nwb_file_name,
                           'pos_merge_id': merge_id,
                           'epoch': 10,
                           'statescript_path': '/stelmo/denisse/Caius/20260623/20260623_Caius_10_r5/20260623_Caius_10_r5.stateScriptLog'}, skip_duplicates = True)

# %%
ForkTrackEvents().populate()
# Out:
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/spec/namespace.py:620: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# ndx-pose - cached version: 0.2.0, loaded version: 0.3.0
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/MarketTech LuxX+ Red/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/Optical fiber 1/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/Optical fiber 2/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/camera_device 1/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/camera_device 2/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# 1782252293.6127312 1782253481.8640392
# 1782252290.8367863 1782253492.2976336
#
# Position validation summary:
#   Total pokes: 97
#   Valid pokes: 96 (99.0%)
#   Invalid pokes: 1
#
# Invalid poke details:
#   Right_poke at t=1782252462.49s, distance=73.7
#
# ======================================================================
# FORK TRACK EVENT VALIDATION REPORT
# ======================================================================
#
# Handle_poke:
#   Ground truth events: 49
#   Processed events: 49
#   Matched events: 49
#   Match rate: 100.0%
#
# Left_poke:
#   Ground truth events: 26
#   Processed events: 26
#   Matched events: 26
#   Match rate: 100.0%
#
# Right_poke:
#   Ground truth events: 22
#   Processed events: 22
#   Matched events: 22
#   Match rate: 100.0%
# [17:26:46][INFO] Spyglass: Writing new NWB file Caius20260623_XREZECQ3BW.nwb
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/MarketTech LuxX+ Red/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/Optical fiber 1/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/Optical fiber 2/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/camera_device 1/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/camera_device 2/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# 1782248113.112781 1782249347.4919808
# 1782248109.293267 1782249354.9369867
#
# Position validation summary:
#   Total pokes: 93
#   Valid pokes: 91 (97.8%)
#   Invalid pokes: 2
#
# Invalid poke details:
#   Handle_poke at t=1782249042.00s, distance=78.1
#   Left_poke at t=1782249055.58s, distance=90.2
#
# ======================================================================
# FORK TRACK EVENT VALIDATION REPORT
# ======================================================================
#
# Handle_poke:
#   Ground truth events: 47
#   Processed events: 47
#   Matched events: 39
#   Match rate: 83.0%
#
# Left_poke:
#   Ground truth events: 24
#   Processed events: 24
#   Matched events: 21
#   Match rate: 87.5%
#
# Right_poke:
#   Ground truth events: 22
#   Processed events: 22
#   Matched events: 17
#   Match rate: 77.3%
# [17:27:05][INFO] Spyglass: Writing new NWB file Caius20260623_BXHBYRF1RX.nwb
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/MarketTech LuxX+ Red/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/Optical fiber 1/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/Optical fiber 2/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/camera_device 1/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# /home/dmrodriguez/miniforge3/envs/spyglass_py310_new/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:620: BrokenLinkWarning: Path to Group altered/broken at /general/devices/camera_device 2/model
#   warnings.warn('Path to Group altered/broken at ' + os.path.join(h5obj.name, k), BrokenLinkWarning)
# {'success_count': 2, 'error_list': []}

# %%
(ForkTrackEvents() & {'epoch': 8}).delete()
# Out:
# [17:17:33][WARNING] Spyglass: Skipping unimported: `jguidera_maze`.`__annotated_universal_track_graph`
# [17:17:33][WARNING] Spyglass: Spawning tables for spikesorting_artifact
# [17:17:33][WARNING] Spyglass: Spawning tables for spikesorting_sorting
# [17:17:34][WARNING] Spyglass: Spawning tables for spikesorting_curation_figurl
# [17:17:34][WARNING] Spyglass: Spawning tables for spikesorting_sortingview
# [17:17:34][WARNING] Spyglass: Skipping unimported: `jguidera_edeno_decoder_helpers`.`track_graph_source_sorted_spikes_classifier_params`
# [17:17:34][WARNING] Spyglass: Skipping unimported: `sc4712_lfp_v1`.`l_f_p_selection_sharon`
# [17:17:34][WARNING] Spyglass: Spawning tables for spikesorting_v1_artifact
# [17:17:34][WARNING] Spyglass: Spawning tables for spikesorting_v1_figurl_curation
# [17:17:34][WARNING] Spyglass: Spawning tables for spikesorting_merge
# [17:17:34][WARNING] Spyglass: Spawning tables for figurl_view_spike_sorting_recording
# [17:17:35][WARNING] Spyglass: Skipping unimported: `ms_ripple`.`__ripple_intervals`
# [17:17:35][WARNING] Spyglass: Spawning tables for decoding_merge
# [17:17:35][WARNING] Spyglass: Skipping unimported: `moseq_v1`.`moseq_syllable_selection`
# [17:17:35][WARNING] Spyglass: Skipping unimported: `ms_place_fields`.`__track_cell_coverage`
# [17:17:35][WARNING] Spyglass: Skipping unimported: `ms_trial_intervals`.`__trial_intervals`
# [17:17:35][WARNING] Spyglass: Skipping unimported: `ms_ripple`.`__ms_lfp_artifact`
# [17:17:35][WARNING] Spyglass: Skipping unimported: `bbaublyte_sleep_scoring`.`sleep_score_selection`
# [17:17:35][WARNING] Spyglass: Skipping unimported: `bbaublyte_sleep_scoring`.`__sleep_score`
# [17:17:35][WARNING] Spyglass: Skipping unimported: `hex_maze`.`hex_position_selection`
# [17:17:35][WARNING] Spyglass: Spawning tables for spikesorting_burst_v0
# [17:17:35][WARNING] Spyglass: Spawning tables for spikesorting_burst_v1
# [17:17:35][WARNING] Spyglass: Skipping unimported: `denissemorales_sleep_scoring`.`sleep_scoring_selection`
# [17:17:35][WARNING] Spyglass: Skipping unimported: `denissemorales_wtrack`.`w_track_selection`
# [17:17:35][WARNING] Spyglass: Spawning tables for spikesorting_v2_figpack_curation
# [17:17:35][INFO] Spyglass: Queueing delete for session(s):
# *nwb_file_name *lab_member_na
# +------------+ +------------+
#
#  (Total: 0)
#
# [2026-07-15 17:17:35,929][INFO]: Deleting 1 rows from `denissemorales_forktrack`.`__fork_track_events`
# [2026-07-15 17:17:37,225][INFO]: Delete committed.

# %%
x = (ForkTrackEvents() & {'nwb_file_name': nwb_file_name}).fetch('validation_report')
x
# Out:
# array([{'position': {'total_pokes': 51, 'valid_pokes': 51, 'invalid_pokes': 0, 'percent_valid': 100.0}, 'log': {'Center_poke': {'ground_truth_count': 12, 'processed_count': 12, 'matched': 12, 'match_rate': 1.0}, 'Handle_poke': {'ground_truth_count': 22, 'processed_count': 22, 'matched': 22, 'match_rate': 1.0}, 'Left_poke': {'ground_truth_count': 7, 'processed_count': 7, 'matched': 7, 'match_rate': 1.0}, 'Right_poke': {'ground_truth_count': 10, 'processed_count': 10, 'matched': 10, 'match_rate': 1.0}}},
#        {'position': {'total_pokes': 80, 'valid_pokes': 80, 'invalid_pokes': 0, 'percent_valid': 100.0}, 'log': {'Center_poke': {'ground_truth_count': 2, 'processed_count': 2, 'matched': 2, 'match_rate': 1.0}, 'Handle_poke': {'ground_truth_count': 40, 'processed_count': 40, 'matched': 40, 'match_rate': 1.0}, 'Left_poke': {'ground_truth_count': 21, 'processed_count': 21, 'matched': 21, 'match_rate': 1.0}, 'Right_poke': {'ground_truth_count': 17, 'processed_count': 17, 'matched': 17, 'match_rate': 1.0}}}],
#       dtype=object)

# %%
x = (ForkTrackEvents() & {'epoch': 2}).fetch('forktrack_results')
y = pd.DataFrame(x[0])
y
y
# Out:
#             time  epoch    well_name    prev_well               transition  \
# 0   1.782236e+09      2  Center_poke         None
# 1   1.782236e+09      2   Right_poke  Center_poke   Center_poke→Right_poke
# 2   1.782236e+09      2  Handle_poke   Right_poke   Right_poke→Handle_poke
# 3   1.782236e+09      2  Center_poke  Handle_poke  Handle_poke→Center_poke
# 4   1.782236e+09      2  Handle_poke  Center_poke  Center_poke→Handle_poke
# 5   1.782236e+09      2    Left_poke  Handle_poke    Handle_poke→Left_poke
# 6   1.782236e+09      2   Right_poke    Left_poke     Left_poke→Right_poke
# 7   1.782236e+09      2  Handle_poke   Right_poke   Right_poke→Handle_poke
# 8   1.782236e+09      2    Left_poke  Handle_poke    Handle_poke→Left_poke
# 9   1.782236e+09      2   Right_poke    Left_poke     Left_poke→Right_poke
# 10  1.782236e+09      2  Handle_poke   Right_poke   Right_poke→Handle_poke
# 11  1.782236e+09      2  Center_poke  Handle_poke  Handle_poke→Center_poke
# 12  1.782236e+09      2   Right_poke  Center_poke   Center_poke→Right_poke
# 13  1.782236e+09      2  Handle_poke   Right_poke   Right_poke→Handle_poke
# 14  1.782237e+09      2  Center_poke  Handle_poke  Handle_poke→Center_poke
# 15  1.782237e+09      2  Handle_poke  Center_poke  Center_poke→Handle_poke
# 16  1.782237e+09      2   Right_poke  Handle_poke   Handle_poke→Right_poke
# 17  1.782237e+09      2    Left_poke   Right_poke     Right_poke→Left_poke
# 18  1.782237e+09      2  Handle_poke    Left_poke    Left_poke→Handle_poke
# 19  1.782237e+09      2   Right_poke  Handle_poke   Handle_poke→Right_poke
# 20  1.782237e+09      2  Handle_poke   Right_poke   Right_poke→Handle_poke
# 21  1.782237e+09      2  Center_poke  Handle_poke  Handle_poke→Center_poke
# 22  1.782237e+09      2  Handle_poke  Center_poke  Center_poke→Handle_poke
# 23  1.782237e+09      2  Center_poke  Handle_poke  Handle_poke→Center_poke
# 24  1.782237e+09      2  Handle_poke  Center_poke  Center_poke→Handle_poke
# 25  1.782237e+09      2  Center_poke  Handle_poke  Handle_poke→Center_poke
# 26  1.782237e+09      2    Left_poke  Center_poke    Center_poke→Left_poke
# 27  1.782237e+09      2  Handle_poke    Left_poke    Left_poke→Handle_poke
# 28  1.782237e+09      2  Center_poke  Handle_poke  Handle_poke→Center_poke
# 29  1.782237e+09      2  Handle_poke  Center_poke  Center_poke→Handle_poke
# 30  1.782237e+09      2   Right_poke  Handle_poke   Handle_poke→Right_poke
# 31  1.782237e+09      2  Handle_poke   Right_poke   Right_poke→Handle_poke
# 32  1.782237e+09      2  Center_poke  Handle_poke  Handle_poke→Center_poke
# 33  1.782237e+09      2  Handle_poke  Center_poke  Center_poke→Handle_poke
# 34  1.782237e+09      2  Center_poke  Handle_poke  Handle_poke→Center_poke
# 35  1.782237e+09      2  Handle_poke  Center_poke  Center_poke→Handle_poke
# 36  1.782237e+09      2  Center_poke  Handle_poke  Handle_poke→Center_poke
# 37  1.782237e+09      2   Right_poke  Center_poke   Center_poke→Right_poke
# 38  1.782237e+09      2  Handle_poke   Right_poke   Right_poke→Handle_poke
# 39  1.782237e+09      2   Right_poke  Handle_poke   Handle_poke→Right_poke
# 40  1.782237e+09      2  Handle_poke   Right_poke   Right_poke→Handle_poke
# 41  1.782237e+09      2    Left_poke  Handle_poke    Handle_poke→Left_poke
# 42  1.782237e+09      2  Handle_poke    Left_poke    Left_poke→Handle_poke
# 43  1.782237e+09      2    Left_poke  Handle_poke    Handle_poke→Left_poke
# 44  1.782237e+09      2  Handle_poke    Left_poke    Left_poke→Handle_poke
# 45  1.782237e+09      2  Center_poke  Handle_poke  Handle_poke→Center_poke
# 46  1.782237e+09      2  Handle_poke  Center_poke  Center_poke→Handle_poke
# 47  1.782237e+09      2   Right_poke  Handle_poke   Handle_poke→Right_poke
# 48  1.782237e+09      2  Handle_poke   Right_poke   Right_poke→Handle_poke
# 49  1.782237e+09      2    Left_poke  Handle_poke    Handle_poke→Left_poke
# 50  1.782237e+09      2  Handle_poke    Left_poke    Left_poke→Handle_poke
#
#    trial_type  pump_triggered     pump_time  pump_delay  time_between_rewards  \
# 0     Inbound           False           NaN         NaN                   NaN
# 1    Outbound           False           NaN         NaN                   NaN
# 2     Inbound            True  1.782236e+09    0.006967                   NaN
# 3     Inbound           False           NaN         NaN                   NaN
# 4     Inbound           False           NaN         NaN                   NaN
# 5    Outbound            True  1.782236e+09    0.006600             45.644552
# 6    Outbound           False           NaN         NaN                   NaN
# 7     Inbound            True  1.782236e+09    0.007000             41.251683
# 8    Outbound            True  1.782236e+09    0.006633             21.872778
# 9    Outbound           False           NaN         NaN                   NaN
# 10    Inbound            True  1.782236e+09    0.007100             36.836514
# 11    Inbound           False           NaN         NaN                   NaN
# 12   Outbound           False           NaN         NaN                   NaN
# 13    Inbound            True  1.782236e+09    0.007100             33.741898
# 14    Inbound           False           NaN         NaN                   NaN
# 15    Inbound           False           NaN         NaN                   NaN
# 16   Outbound           False           NaN         NaN                   NaN
# 17   Outbound           False           NaN         NaN                   NaN
# 18    Inbound            True  1.782237e+09    0.007133            108.302972
# 19   Outbound            True  1.782237e+09    0.006900             34.784748
# 20    Inbound            True  1.782237e+09    0.007067             24.620121
# 21    Inbound           False           NaN         NaN                   NaN
# 22    Inbound           False           NaN         NaN                   NaN
# 23    Inbound           False           NaN         NaN                   NaN
# 24    Inbound           False           NaN         NaN                   NaN
# 25    Inbound           False           NaN         NaN                   NaN
# 26   Outbound           False           NaN         NaN                   NaN
# 27    Inbound            True  1.782237e+09    0.007133            201.967381
# 28    Inbound           False           NaN         NaN                   NaN
# 29    Inbound           False           NaN         NaN                   NaN
# 30   Outbound            True  1.782237e+09    0.006900            141.859901
# 31    Inbound            True  1.782237e+09    0.007167             34.015636
# 32    Inbound           False           NaN         NaN                   NaN
# 33    Inbound           False           NaN         NaN                   NaN
# 34    Inbound           False           NaN         NaN                   NaN
# 35    Inbound           False           NaN         NaN                   NaN
# 36    Inbound           False           NaN         NaN                   NaN
# 37   Outbound           False           NaN         NaN                   NaN
# 38    Inbound            True  1.782237e+09    0.007133             86.337960
# 39   Outbound           False           NaN         NaN                   NaN
# 40    Inbound            True  1.782237e+09    0.007133             48.204326
# 41   Outbound            True  1.782237e+09    0.006800             25.287498
# 42    Inbound            True  1.782237e+09    0.007133             23.768141
# 43   Outbound           False           NaN         NaN                   NaN
# 44    Inbound            True  1.782237e+09    0.007067             74.437139
# 45    Inbound           False           NaN         NaN                   NaN
# 46    Inbound           False           NaN         NaN                   NaN
# 47   Outbound            True  1.782237e+09    0.006900             63.494033
# 48    Inbound            True  1.782237e+09    0.007133             22.474621
# 49   Outbound            True  1.782237e+09    0.006800             22.621090
# 50    Inbound            True  1.782237e+09    0.007133             30.528080
#
#     position_valid
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# 5             True
# 6             True
# 7             True
# 8             True
# 9             True
# 10            True
# 11            True
# 12            True
# 13            True
# 14            True
# 15            True
# 16            True
# 17            True
# 18            True
# 19            True
# 20            True
# 21            True
# 22            True
# 23            True
# 24            True
# 25            True
# 26            True
# 27            True
# 28            True
# 29            True
# 30            True
# 31            True
# 32            True
# 33            True
# 34            True
# 35            True
# 36            True
# 37            True
# 38            True
# 39            True
# 40            True
# 41            True
# 42            True
# 43            True
# 44            True
# 45            True
# 46            True
# 47            True
# 48            True
# 49            True
# 50            True

# %%
x = (WTrackEvents() & {'epoch': 2}).fetch('wtrack_results')
y = pd.DataFrame(x[0])
y
y
