# %%
import datajoint as dj
dj.config.load("dj_local_conf.json")

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import pandas as pd
from scipy.ndimage import gaussian_filter1d

from spyglass.position.position_merge import PositionOutput
import spyglass.lfp as lfp
from spyglass.lfp.analysis.v1 import lfp_band
# Out:
# /home/dmrodriguez/miniforge3/envs/mPFC-opto/lib/python3.10/site-packages/datajoint/plugin.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2026-01-19 11:46:42,343][INFO]: DataJoint is configured from /home/dmrodriguez/mPFC-opto/notebooks/dj_local_conf.json
# [2026-01-19 11:46:43,534][INFO]: DataJoint 0.14.6 connected to denissemorales@lmf-db.cin.ucsf.edu:3306

# %%
from sleep.sleep_table_dmr import SleepScoringParams, SleepScoringSelection, SleepScoring

# define nwb_file, interval list, filter names, and lfp electrodes

nwb_file_name = 'Jacob20250617_.nwb'
lfp_electrode_group_name = 'Left and Right CA1 Hippocampus'
interval_list_name = '03_s2'

lfp_filter = "LFP 0-400 Hz"
delta_filter = 'Delta 0.5-4 Hz'
theta_filter = 'Theta 5-11 Hz'
emg_filter = 'EMG 300-600'

sampling_rate = 1000

# %%
# Here, method can be hierarchical, GMM, or Kmeans. Use hierarchical just means
# you distinguish sleep from wake first, as opposed to clustering wake/NREM/REM
# at the same time

SleepScoringParams()
# Out:
# *sleep_scoring method         use_hierarchic use_pss     power_smoothin speed_smoothin apply_constrai rem_cannot_fol constraint_max min_duration   speed_threshol use_speed_for_
# +------------+ +------------+ +------------+ +---------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
# hierarchical   hierarchical   1              0           0.5            0.5            1              1              15             5.0            3.0            1
#  (Total: 1)

# %%
lfp_s_key = {
    "nwb_file_name": nwb_file_name,
    "lfp_electrode_group_name": lfp_electrode_group_name,
    "target_interval_list_name": interval_list_name,
    "filter_name": lfp_filter,
    "target_sampling_rate": sampling_rate
}

lfp_merge_id = (lfp.LFPOutput.LFPV1() & lfp_s_key).fetch1("merge_id")


theta_merge_id = (lfp_band.LFPBandV1 & {'filter_name': theta_filter,
                                   'nwb_file_name': nwb_file_name,
                                  'target_interval_list_name': interval_list_name}).fetch1('lfp_merge_id')
delta_merge_id = (lfp_band.LFPBandV1 & {'filter_name': delta_filter,
                                   'nwb_file_name': nwb_file_name,
                                  'target_interval_list_name': interval_list_name}).fetch1('lfp_merge_id')

# %%
lfp_band.LFPBandV1() & {
                        'filter_name': emg_filter}
# Out:
# *lfp_merge_id  *filter_name   *filter_sampli *nwb_file_name *target_interv *lfp_band_samp analysis_file_ interval_list_ lfp_band_objec
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
#
#  (Total: 0)

# %%
pos_key = (PositionOutput.TrodesPosV1() & {'nwb_file_name': nwb_file_name,
                             'interval_list_name': "pos 0 valid times",
                             'trodes_pos_params_name': 'single_led'}).fetch1("KEY")
pos_merge_id = pos_key['merge_id']

# %%
key = [{'sleep_scoring_params_name': 'hierarchical',
       'lfp_merge_id': lfp_merge_id,
       'nwb_file_name': nwb_file_name,
        'filter_sampling_rate': sampling_rate,
        'target_interval_list_name': '03_s2',
        'pos_merge_id':pos_key['merge_id'],
        'theta_filter_name': theta_filter,
        'delta_filter_name': delta_filter,
        'emg_filter_name': None,
        'pss_filter_name': None,
        'emg_merge_id': None,
        'pss_merge_id': None
}]

# %%
position_df = (PositionOutput & pos_key).fetch1_dataframe()

# %%
position_df
# Out:
#               video_frame_ind  position_x  position_y  orientation  \
# time
# 1.750178e+09                0       40.29      23.052          NaN
# 1.750178e+09                1       40.29      23.052          NaN
# 1.750178e+09                2       40.29      23.052          NaN
# 1.750178e+09                3       40.29      23.052          NaN
# 1.750178e+09                4       40.29      23.052          NaN
# ...                       ...         ...         ...          ...
# 1.750179e+09            54780       40.29      23.052          NaN
# 1.750179e+09            54781       40.29      23.052          NaN
# 1.750179e+09            54782       40.29      23.052          NaN
# 1.750179e+09            54783       40.29      23.052          NaN
# 1.750179e+09            54784       40.29      23.052          NaN
#
#                 velocity_x    velocity_y         speed
# time
# 1.750178e+09  6.216477e-15 -1.320098e-14  1.459145e-14
# 1.750178e+09  9.169628e-15 -1.470617e-14  1.733071e-14
# 1.750178e+09  1.210399e-14 -1.470617e-14  1.904673e-14
# 1.750178e+09  1.429797e-14 -1.320098e-14  1.946016e-14
# 1.750178e+09  1.511436e-14 -1.063681e-14  1.848204e-14
# ...                    ...           ...           ...
# 1.750179e+09 -8.865047e-15 -6.051994e-15  1.073386e-14
# 1.750179e+09 -6.093618e-15 -4.584814e-15  7.625791e-15
# 1.750179e+09 -3.727273e-15 -3.108238e-15  4.853217e-15
# 1.750179e+09 -2.033410e-15 -1.885716e-15  2.773208e-15
# 1.750179e+09 -9.907574e-16 -1.023782e-15  1.424686e-15
#
# [54785 rows x 7 columns]

# %%
key
# Out:
# [{'sleep_scoring_params_name': 'hierarchical',
#   'lfp_merge_id': UUID('f8b497a4-75a1-dafe-2c37-da68ad87f0af'),
#   'nwb_file_name': 'Jacob20250617_.nwb',
#   'filter_sampling_rate': 1000,
#   'target_interval_list_name': '03_s2',
#   'pos_merge_id': UUID('aee5cc01-03a0-f552-5c4f-4b9cb28b6314'),
#   'theta_filter_name': 'Theta 5-11 Hz',
#   'delta_filter_name': 'Delta 0.5-4 Hz',
#   'emg_filter_name': None,
#   'pss_filter_name': None,
#   'emg_merge_id': None,
#   'pss_merge_id': None}]

# %%
SleepScoringSelection().drop()
# Out:
# [2026-01-18 12:30:32,100][INFO]: `denissemorales_sleepscoring`.`sleep_scoring_selection` (2 tuples)
# [2026-01-18 12:30:32,221][INFO]: `denissemorales_sleepscoring`.`__sleep_scoring` (2 tuples)
# [2026-01-18 12:30:33,837][INFO]: Dropped table `denissemorales_sleepscoring`.`__sleep_scoring`
# [2026-01-18 12:30:33,979][INFO]: Dropped table `denissemorales_sleepscoring`.`sleep_scoring_selection`
# [2026-01-18 12:30:34,010][INFO]: Tables dropped. Restart kernel.

# %%
SleepScoringSelection().insert(key, skip_duplicates = True)

# %%
SleepScoring()
# Out:
# *sleep_scoring *target_interv *nwb_file_name *theta_filter_ *delta_filter_ *lfp_merge_id  state_labe timestamps nrem_duration  rem_duration   wake_duration  nrem_percentag rem_percentage wake_percentag analysis_file_ trial_object_i
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +--------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
#
#  (Total: 0)

# %%
SleepScoring().drop()
# Out:
# [2026-01-19 11:46:35,502][INFO]: `denissemorales_sleepscoring`.`__sleep_scoring` (0 tuples)
# [2026-01-19 11:46:37,072][INFO]: Dropped table `denissemorales_sleepscoring`.`__sleep_scoring`
# [2026-01-19 11:46:37,099][INFO]: Tables dropped. Restart kernel.

# %%
SleepScoring.populate()
# Out:
# /home/dmrodriguez/miniforge3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# ndx-franklab-novela - cached version: 0.2.0, loaded version: 0.2.3
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/dmrodriguez/miniforge3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# ndx-franklab-novela - cached version: 0.2.0, loaded version: 0.2.3
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/dmrodriguez/miniforge3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.3
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# Wake detection using head speed: 0 epochs WAKE
# NREM epochs: 1827817, REM epochs: 1
# REM fallback applied: 169465 epochs set to REM
# {'success_count': 1, 'error_list': []}

# %%
import spyglass.common as sgc
sgc.IntervalList().check_threads()
# Out:
# Empty DataFrame
# Columns: [Locked, Name, Time (s), Process, State]
# Index: []

# %%
SleepScoring().drop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 SleepScoring().drop()
#
# NameError: name 'SleepScoring' is not defined

# %%
import numpy as np

sws_intervals = np.array([[1.62230601e+09, 1.62230607e+09],
                          [1.62230628e+09, 1.62230629e+09],
                          [1.62230631e+09, 1.62230632e+09],
                          [1.62230636e+09, 1.62230643e+09],
                          [1.62230646e+09, 1.62230656e+09],
                          [1.62230657e+09, 1.62230664e+09],
                          [1.62230694e+09, 1.62230697e+09],
                          [1.62230698e+09, 1.62230735e+09],
                          [1.62230738e+09, 1.62230750e+09],
                          [1.62230753e+09, 1.62230784e+09],
                          [1.62230791e+09, 1.62230809e+09],
                          [1.62230810e+09, 1.62230820e+09]])

rem_intervals = np.array([[1.62230629e+09, 1.62230631e+09],
                          [1.62230632e+09, 1.62230633e+09],
                          [1.62230635e+09, 1.62230636e+09],
                          [1.62230656e+09, 1.62230657e+09],
                          [1.62230676e+09, 1.62230677e+09],
                          [1.62230688e+09, 1.62230688e+09],
                          [1.62230735e+09, 1.62230738e+09],
                          [1.62230750e+09, 1.62230753e+09],
                          [1.62230784e+09, 1.62230791e+09],
                          [1.62230820e+09, 1.62230836e+09],
                          [1.62230843e+09, 1.62230844e+09]])

# Calculate total durations
total_nrem = np.sum(sws_intervals[:,1] - sws_intervals[:,0])
total_rem  = np.sum(rem_intervals[:,1] - rem_intervals[:,0])

# REM/NREM duration ratio
rem_to_nrem_ratio = total_rem / total_nrem

total_nrem, total_rem, rem_to_nrem_ratio
# Out:
# (1430.0, 360.0, 0.2517482517482518)

# %%
SleepScoring() & {'nwb_file_name': 'J1620210529_.nwb'}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 SleepScoring() & {'nwb_file_name': 'J1620210529_.nwb'}
#
# NameError: name 'SleepScoring' is not defined

# %%
(SleepScoring() & {'nwb_file_name': 'J1620210529_.nwb'}).fetch_nrem_times()
# Out:
# array([[1.62230589e+09, 1.62230590e+09],
#        [1.62230593e+09, 1.62230594e+09],
#        [1.62230595e+09, 1.62230622e+09],
#        [1.62230624e+09, 1.62230678e+09],
#        [1.62230679e+09, 1.62230680e+09],
#        [1.62230682e+09, 1.62230683e+09],
#        [1.62230685e+09, 1.62230690e+09],
#        [1.62230690e+09, 1.62230847e+09],
#        [1.62230851e+09, 1.62230851e+09],
#        [1.62230856e+09, 1.62230857e+09]])

# %%
[[1.62230601e+09, 1.62230607e+09],
              [1.62230628e+09, 1.62230629e+09],
              [1.62230631e+09, 1.62230632e+09],
              [1.62230636e+09, 1.62230643e+09],
              [1.62230646e+09, 1.62230656e+09],
              [1.62230657e+09, 1.62230664e+09],
              [1.62230694e+09, 1.62230697e+09],
              [1.62230698e+09, 1.62230735e+09],
              [1.62230738e+09, 1.62230750e+09],
              [1.62230753e+09, 1.62230784e+09],
              [1.62230791e+09, 1.62230809e+09],
              [1.62230810e+09, 1.62230820e+09]]
# Out:
# [[1622306010.0, 1622306070.0],
#  [1622306280.0, 1622306290.0],
#  [1622306310.0, 1622306320.0],
#  [1622306360.0, 1622306430.0],
#  [1622306460.0, 1622306560.0],
#  [1622306570.0, 1622306640.0],
#  [1622306940.0, 1622306970.0],
#  [1622306980.0, 1622307350.0],
#  [1622307380.0, 1622307500.0],
#  [1622307530.0, 1622307840.0],
#  [1622307910.0, 1622308090.0],
#  [1622308100.0, 1622308200.0]]

# %%
import spyglass.common as sgc
# interval_list_name = 'pos 2 valid times'
# nwb_file_name = 'J1620210529_.nwb'

interval_list_name = '03_s2'
nwb_file_name = 'Jacob20250617_.nwb'

interval_list_name = f"{interval_list_name}_rem"
(sgc.IntervalList() & {
    'nwb_file_name': nwb_file_name,
    'interval_list_name': interval_list_name
}).delete()
# Out:
# [2026-01-15 14:05:14,195][WARNING]: Reconnecting to MySQL server.
# [14:05:14][WARNING] Spyglass: Spawning tables for decoding_clusterless
# [14:05:14][WARNING] Spyglass: Spawning tables for decoding_sortedspikes
# [14:05:14][WARNING] Spyglass: Skipping unimported: `jguidera_maze`.`__annotated_universal_track_graph`
# [14:05:14][WARNING] Spyglass: Spawning tables for sharing_kachery
# [14:05:14][WARNING] Spyglass: Spawning tables for spikesorting_curation
# [14:05:14][WARNING] Spyglass: Spawning tables for spikesorting_recording
# [14:05:15][WARNING] Spyglass: Skipping unimported: `sc4712_lfp_v1`.`l_f_p_selection_sharon`
# [14:05:15][WARNING] Spyglass: Spawning tables for spikesorting_v1_recording
# [14:05:15][WARNING] Spyglass: Spawning tables for spikesorting_v1_sorting
# [14:05:15][WARNING] Spyglass: Spawning tables for spikesorting_v1_curation
# [14:05:15][WARNING] Spyglass: Spawning tables for spikesorting_v1_metric_curation
# [14:05:15][WARNING] Spyglass: Spawning tables for spikesorting_imported
# [14:05:15][WARNING] Spyglass: Spawning tables for decoding_waveform_features
# [14:05:15][WARNING] Spyglass: Spawning tables for spikesorting_group_v1
# [14:05:15][WARNING] Spyglass: Spawning tables for mua_v1
# [14:05:15][WARNING] Spyglass: Spawning tables for common_dandi
# [14:05:15][WARNING] Spyglass: Skipping unimported: `ms_ripple`.`__ripple_intervals`
# [14:05:15][WARNING] Spyglass: Spawning tables for ripple_v1
# [14:05:16][WARNING] Spyglass: Spawning tables for behavior_v1_core
# [14:05:16][WARNING] Spyglass: Spawning tables for decoding_clusterless_v1
# [14:05:16][WARNING] Spyglass: Spawning tables for decoding_core_v1
# [14:05:16][WARNING] Spyglass: Skipping unimported: `moseq_v1`.`moseq_syllable_selection`
# [14:05:16][WARNING] Spyglass: Skipping unimported: `ms_place_fields`.`__track_cell_coverage`
# [14:05:16][WARNING] Spyglass: Skipping unimported: `ms_trial_intervals`.`__trial_intervals`
# [14:05:16][WARNING] Spyglass: Spawning tables for position_linearization_merge
# [14:05:16][WARNING] Spyglass: Spawning tables for position_linearization_v1
# [14:05:16][WARNING] Spyglass: Spawning tables for decoding_sorted_spikes_v1
# [14:05:16][WARNING] Spyglass: Skipping unimported: `ms_ripple`.`__ms_lfp_artifact`
# [14:05:16][WARNING] Spyglass: Skipping unimported: `bbaublyte_sleep_scoring`.`sleep_score_selection`
# [14:05:16][WARNING] Spyglass: Skipping unimported: `bbaublyte_sleep_scoring`.`sleep_score_selection`
# [14:05:16][WARNING] Spyglass: Skipping unimported: `bbaublyte_sleep_scoring`.`sleep_score_selection`
# [14:05:16][WARNING] Spyglass: Skipping unimported: `bbaublyte_sleep_scoring`.`__sleep_score`
# [14:05:16][WARNING] Spyglass: Skipping unimported: `bbaublyte_sleep_scoring`.`__sleep_score`
# [14:05:16][WARNING] Spyglass: Skipping unimported: `hex_maze`.`hex_position_selection`
# [14:05:16][WARNING] Spyglass: Spawning tables for spikesorting_linear_assembly_v1
# [14:05:16][WARNING] Spyglass: Spawning tables for behavior_v1_moseq
# [14:05:16][WARNING] Spyglass: Skipping unimported: `denissemorales_sleep_scoring`.`sleep_scoring_selection`
# [14:05:16][WARNING] Spyglass: Skipping unimported: `denissemorales_sleep_scoring`.`sleep_scoring_selection`
# [14:05:16][WARNING] Spyglass: Skipping unimported: `denissemorales_sleep_scoring`.`sleep_scoring_selection`
# [14:05:16][WARNING] Spyglass: Spawning tables for spikesorting_recompute_v0
# [14:05:17][WARNING] Spyglass: Spawning tables for spikesorting_v1_recompute
# [14:05:17][WARNING] Spyglass: Skipping unimported: `denissemorales_wtrack`.`w_track_selection`
# [14:05:17][INFO] Spyglass: Queueing delete for session(s):
# *nwb_file_name *lab_member_na
# +------------+ +------------+
# Jacob20250617_ Chenyan Liu
# Jacob20250617_ Denisse Morale
# Jacob20250617_ Kyu Hyun Lee
# Jacob20250617_ Scott Gao
#  (Total: 4)
#
# [2026-01-15 14:05:28,491][WARNING]: Reconnecting to MySQL server.
# ---------------------------------------------------------------------------
# LostConnectionError                       Traceback (most recent call last)
# Cell In[8], line 9
#       6 nwb_file_name = 'Jacob20250617_.nwb'
#       8 interval_list_name = f"{interval_list_name}_rem"
# ----> 9 (sgc.IntervalList() & {
#      10     'nwb_file_name': nwb_file_name,
#      11     'interval_list_name': interval_list_name
#      12 }).delete()
#
# File ~/spyglass/src/spyglass/utils/mixins/cautious_delete.py:247, in CautiousDeleteMixin.delete(self, *args, **kwargs)
#     245 def delete(self, *args, **kwargs):
#     246     """Alias for cautious_delete, overwrites datajoint.table.Table.delete"""
# --> 247     self.cautious_delete(*args, **kwargs)
#
# File ~/spyglass/src/spyglass/utils/mixins/cautious_delete.py:236, in CautiousDeleteMixin.cautious_delete(self, force_permission, dry_run, *args, **kwargs)
#     229 if dry_run:
#     230     return (
#     231         IntervalList(),  # cleanup func relies on downstream deletes
#     232         external["raw"].unused(),
#     233         external["analysis"].unused(),
#     234     )
# --> 236 super().delete(*args, **kwargs)  # Confirmation here
#     238 for ext_type in ["raw", "analysis"]:
#     239     external[ext_type].delete(
#     240         delete_external_files=True, display_progress=False
#     241     )
#
# File ~/miniforge3/envs/spyglass/lib/python3.9/site-packages/datajoint/table.py:634, in Table.delete(self, transaction, safemode, force_parts, force_masters)
#     632 except:
#     633     if transaction:
# --> 634         self.connection.cancel_transaction()
#     635     raise
#     637 if not force_parts:
#     638     # Avoid deleting from child before master (See issue #151)
#
# File ~/miniforge3/envs/spyglass/lib/python3.9/site-packages/datajoint/connection.py:401, in Connection.cancel_transaction(self)
#     397 def cancel_transaction(self):
#     398     """
#     399     Cancels the current transaction and rolls back all changes made during the transaction.
#     400     """
# --> 401     self.query("ROLLBACK")
#     402     self._in_transaction = False
#     403     logger.debug("Transaction cancelled. Rolling back ...")
#
# File ~/miniforge3/envs/spyglass/lib/python3.9/site-packages/datajoint/connection.py:358, in Connection.query(self, query, args, as_dict, suppress_warnings, reconnect)
#     356 if self._in_transaction:
#     357     self.cancel_transaction()
# --> 358     raise errors.LostConnectionError(
#     359         "Connection was lost during a transaction."
#     360     )
#     361 logger.debug("Re-executing")
#     362 cursor = self._conn.cursor(cursor=cursor_class)
#
# LostConnectionError: Connection was lost during a transaction.

# %%
nwb_file_name = 'J1620210529_.nwb'
lfp_electrode_group_name = 'all_tets_J16'
interval_list_name = 'pos 2 valid times'

lfp_filter = "LFP 0-400 Hz"
delta_filter = 'Delta 0.5-4 Hz'
theta_filter = 'Theta 5-11 Hz'
emg_filter = 'EMG 300-6/00 DMR'
sampling_rate = 1000

lfp_key = '2c3a6142-c62c-0ba8-2b35-d083790590e5'

lfp_deltaband_key = (
    lfp_band.LFPBandSelection
    & {
        "lfp_merge_id": lfp_key,
        "filter_name": delta_filter,
        "lfp_band_sampling_rate": 1000,
        'target_interval_list_name': interval_list_name
    }
).fetch1("KEY")

lfp_thetaband_key = (
    lfp_band.LFPBandSelection
    & {
        "lfp_merge_id": lfp_key,
        "filter_name": theta_filter,
        "lfp_band_sampling_rate": 1000,
        'target_interval_list_name': interval_list_name
    }
).fetch1("KEY")

pos_key = (PositionOutput.TrodesPosV1() & {'nwb_file_name': nwb_file_name,
                             'interval_list_name': 'pos 2 valid times'}
           ).fetch1("KEY")

# %%
key = [{'sleep_scoring_params_name': 'hierarchical',
       'lfp_merge_id': lfp_key,
       'nwb_file_name': nwb_file_name,
        'filter_sampling_rate': sampling_rate,
        'target_interval_list_name': interval_list_name,
        'pos_merge_id':pos_key['merge_id'],
        'theta_filter_name': theta_filter,
        'delta_filter_name': delta_filter,
        'emg_filter_name': None,
        'pss_filter_name': None,
        'emg_merge_id': None,
        'pss_merge_id': None
}]

# %%
SleepScoringSelection().insert(key, skip_duplicates = True)

# %%
SleepScoring.populate()
# Out:
# /home/dmrodriguez/miniforge3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.8.0, loaded version: 2.7.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.3
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/dmrodriguez/miniforge3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# ndx-franklab-novela - cached version: 0.2.0, loaded version: 0.2.3
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# Using head speed for wake: 291124 wake epochs
# REM fallback applied: 230072 epochs set to REM
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 SleepScoring.populate()
#
# File ~/spyglass/src/spyglass/utils/mixins/populate.py:98, in PopulateMixin.populate(self, *restrictions, **kwargs)
#      96 if use_transact:  # Pass single-process populate to super
#      97     kwargs["processes"] = processes
# ---> 98     return super().populate(*restrictions, **kwargs)
#      99 else:  # No transaction protection, use bare make
#     100     for key in keys:
#
# File ~/miniforge3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py:319, in AutoPopulate.populate(self, keys, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, processes, make_kwargs, *restrictions)
#     313 if processes == 1:
#     314     for key in (
#     315         tqdm(keys, desc=self.__class__.__name__)
#     316         if display_progress
#     317         else keys
#     318     ):
# --> 319         status = self._populate1(key, jobs, **populate_kwargs)
#     320         if status is True:
#     321             success_list.append(1)
#
# File ~/miniforge3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py:397, in AutoPopulate._populate1(self, key, jobs, suppress_errors, return_exception_objects, make_kwargs)
#     395 try:
#     396     if not is_generator:
# --> 397         make(dict(key), **(make_kwargs or {}))
#     398     else:
#     399         # tripartite make - transaction is delayed until the final stage
#     400         gen = make(dict(key), **(make_kwargs or {}))
#
# File ~/spyglass/notebooks/sleep_table_dmr.py:242, in SleepScoring.make(self, key)
#     229 rem_key = {
#     230     "nwb_file_name": nwb_file_name,
#     231     "interval_list_name": f"{interval_list_name}_rem",
#     232     "valid_times": rem_intervals,
#     233     "pipeline": self.full_table_name,
#     234 }
#     235 wake_key = {
#     236     "nwb_file_name": nwb_file_name,
#     237     "interval_list_name": f"{interval_list_name}_wake",
#     238     "valid_times": wake_intervals,
#     239     "pipeline": self.full_table_name,
#     240 }
# --> 242 IntervalList.insert([nrem_key, rem_key, wake_key], skip_duplicates=True)
#     244 # Insert results
#     245 insert_key = {
#     246     **key,
#     247     "nrem_interval_list_name": f"{interval_list_name}_nrem",
#    (...)
#     257     "wake_percentage": 100 * wake_duration / total_time,
#     258 }
#
# File ~/spyglass/src/spyglass/common/common_interval.py:247, in IntervalList.insert(self, *args, **kwargs)
#     245 def insert(self, *args, **kwargs):
#     246     """Insert with cautious insert by default."""
# --> 247     self.cautious_insert(*args, **kwargs)
#
# File ~/spyglass/src/spyglass/common/common_interval.py:302, in IntervalList.cautious_insert(self, inserts, update, **kwargs)
#     300         self.update1(row)
#     301 elif need_update:
# --> 302     raise ValueError(
#     303         f"Found {len(need_update)} rows with existing names, but "
#     304         + f"different times:{need_update}"
#     305     )
#
# ValueError: Found 2 rows with existing names, but different times:[{'nwb_file_name': 'J1620210529_.nwb', 'interval_list_name': 'pos 2 valid times_nrem', 'valid_times': array([[1.62230593e+09, 1.62230594e+09],
#        [1.62230596e+09, 1.62230622e+09],
#        [1.62230624e+09, 1.62230678e+09],
#        [1.62230682e+09, 1.62230683e+09],
#        [1.62230685e+09, 1.62230690e+09],
#        [1.62230690e+09, 1.62230847e+09],
#        [1.62230856e+09, 1.62230857e+09]]), 'pipeline': '`denissemorales_sleepscoring`.`__sleep_scoring`'}, {'nwb_file_name': 'J1620210529_.nwb', 'interval_list_name': 'pos 2 valid times_wake', 'valid_times': array([[1.62230587e+09, 1.62230593e+09],
#        [1.62230594e+09, 1.62230596e+09],
#        [1.62230622e+09, 1.62230624e+09],
#        [1.62230678e+09, 1.62230682e+09],
#        [1.62230683e+09, 1.62230685e+09],
#        [1.62230690e+09, 1.62230690e+09],
#        [1.62230847e+09, 1.62230856e+09]]), 'pipeline': '`denissemorales_sleepscoring`.`__sleep_scoring`'}]

# %%
(SleepScoring() & key).fetch_nrem_times()
# Out:
# array([[1.62230589e+09, 1.62230590e+09],
#        [1.62230593e+09, 1.62230594e+09],
#        [1.62230595e+09, 1.62230622e+09],
#        [1.62230624e+09, 1.62230678e+09],
#        [1.62230679e+09, 1.62230680e+09],
#        [1.62230682e+09, 1.62230683e+09],
#        [1.62230685e+09, 1.62230690e+09],
#        [1.62230690e+09, 1.62230847e+09],
#        [1.62230851e+09, 1.62230851e+09],
#        [1.62230856e+09, 1.62230857e+09]])

# %%
SleepScoring() & key
# Out:
# *sleep_scoring *target_interv *nwb_file_name *theta_filter_ *delta_filter_ *lfp_merge_id  nrem_interval_ rem_interval_l wake_interval_ state_labe timestamps nrem_duration  rem_duration   wake_duration  nrem_percentag rem_percentage wake_percentag
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +--------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
# hierarchical   pos 2 valid ti J1620210529_.n Theta 5-11 Hz  Delta 0.5-4 Hz 2c3a6142-c62c- pos 2 valid ti pos 2 valid ti pos 2 valid ti =BLOB=     =BLOB=     2489.03        0.0            210.801        92.1914        0.0            7.80787
#  (Total: 1)
